# %%
import pandas as pd
df = pd.DataFrame()
df['learner_name'] = ["sudharsan"]
df["course"] = ["datascience"]
df['batch'] = ["d101"]
df['institute'] = ["guvi"]
df['topic'] = ['mini_project_trial']
df
# Out:
#   learner_name       course batch institute            topic
# 0    sudharsan  datascience  d101      guvi  python basics 2

# %%
import simple_colors
print(simple_colors.yellow("letters are case sensetive.use uppercase and lower case carefully\n"))
#)depatature
source = 'chennai'
print(simple_colors.green(f"source is:\n {source}\n"))

#) destination
destination = 'salem'
print(simple_colors.cyan(f"destination is:\n {destination}\n"))

#)one halt
one_stop = 'attur'
print(simple_colors.yellow(f"one stop is:\n {one_stop}\n"))

passenger_name = input("Enter your name:")
passenger_name = str (passenger_name)
print(simple_colors.red(f"booker name:{passenger_name}\n"))
name_length = len(passenger_name)
print(simple_colors.green(f"length of passenger name:{name_length}\n"))

cotraveller_name_list = []
cotraveller_age_list = []
birth_preference_list = []
if name_length>0:
    passenger_age = input("your age:")
    passenger_age = int (passenger_age)
    print(f"booker age{passenger_age}")
    if passenger_age >= 12:
        print(simple_colors.cyan("destination available:salem or attur\n"))
        destination_preferred = input("enter your choice of destination:")
        if destination_preferred == 'salem':
            print(simple_colors.yellow(""" 4 types of coach is available:AC1/AC2/AC3/SLEEPER\nfare of AC1:800,
fare of AC2:600\nfare of AC3:400\nfare of AC3:200\nfare of SLEEPER:100\n"""))
            coach_preferred = input("your choice of coach:")
            if coach_preferred == 'AC1' or coach_preferred == 'AC2' or coach_preferred == 'AC3' or coach_preferred == 'SLEEPER':
                cotraveller_num = input("how many trallverllers?")
                cotraveller_num = int (cotraveller_num)
                print(f"number of cotravellers: {cotraveller_num}")
                for cotraveller_name in range (0,cotraveller_num):
                    cotraveller_names = input("the traveller name:")
                    cotraveller_names = str (cotraveller_names)
                    cotraveller_age = input("the traveller age:")
                    cotraveller_age = int (cotraveller_age)
                    cotraveller_name_list.append(cotraveller_names)
                    cotraveller_age_list.append(cotraveller_age)
            else:
                print(simple_colors.cyan("you have not entered coach name\n"))
        elif destination_preferred == 'attur':
            print(simple_colors.green("2 types of coach is available:AC3/SLEEPER\nfare of AC3:300\nfare of SLEEPER:50\n"))
            coach_preferred = input("your choice of coach:")
            print(f"coach preferred:{coach_preferred}\n")
            if coach_preferred == 'AC1' or coach_preferred == 'AC2' or coach_preferred == 'AC3' or coach_preferred == 'SLEEPER':
                traveller_num = input("how many trallverllers?")
                traveller_num = int (traveller_num)
                for cotraveller_name in range (0,traveller_num):
                    cotraveller_names = input("the traveller name")
                    cotraveller_names = str (cotraveller_names)
                    cotraveller_age = input("the traveller age")
                    cotraveller_age = int (cotraveller_age)
                    cotraveller_name_list.append(cotraveller_names)
                    cotraveller_age_list.append(cotraveller_age)
            else:
                print(simple_colors.yellow("you have not entered coach name\n"))
        else:
            print(simple_colors.cyan("enter destination correctly\n"))
    else:
        print(simple_colors.green("you are child! not allowed to book the ticket\n"))
else:
    print(simple_colors.yellow("Enter your name correctly\n"))

print(simple_colors.cyan(f"cotraveller name: {cotraveller_name_list}\n"))
print(simple_colors.green(f"cotraveller age: {cotraveller_age_list}\n"))

#) to get co travellers dataframe
import pandas as pd
cotrallevers_df = pd.DataFrame()
cotrallevers_df['cotrallevers_name'] = cotraveller_name_list
cotrallevers_df['cotrallevers_age'] = cotraveller_age_list
print(simple_colors.yellow(f"cotravellers dataframe\n {cotrallevers_df}\n"))

#) to get the ticket fare
cotraveller_age_list
index = 0
senoir_count = 0
#) to get the passenger price
while index < len(cotraveller_age_list):
    age_check = cotraveller_age_list[index]
    if age_check >= 60:
        #) to get senior citizen
        df_senior = cotrallevers_df[cotrallevers_df['cotrallevers_age'] >= 60]
        senior_name_list = df_senior['cotrallevers_name'].tolist()
        senior_age_list = df_senior['cotrallevers_age'].tolist()
        senior_count = len(senior_age_list)
        ticket_price_senior = senior_count*6000*0.6
        print(simple_colors.cyan(f"senior citizen dataframe:\n{df_senior}\n"))
        print(simple_colors.green(f"senior name:{senior_name_list}\n"))
        print(simple_colors.yellow(f"senior age: {senior_age_list}\n"))
        print(simple_colors.cyan(f"number of seniors {senior_count}\n"))
        print(simple_colors.green(f"total ticket price of seniors in the travellers list:\n{ticket_price_senior}\n"))
    elif age_check < 60:
        #) to get junior citizen
        df_junior = cotrallevers_df[cotrallevers_df['cotrallevers_age'] < 60]
        junior_name_list = df_junior['cotrallevers_name'].tolist()
        junior_age_list = df_junior['cotrallevers_age'].tolist()
        junior_count = len(junior_age_list)
        ticket_price_junior = junior_count*6000
        print(simple_colors.cyan(f"junior citizen dataframe:\n{df_junior}\n"))
        print(simple_colors.yellow(f"junior name:{junior_name_list}\n"))
        print(simple_colors.green(f"junior age: {junior_age_list}\n"))
        print(simple_colors.yellow(f"number of juniors {junior_count}\n"))
        print(simple_colors.cyan(f"total ticket price of juniors in the travellers list:\n{ticket_price_junior}\n"))
    index+=1
    if age_check >= 60 and age_check < 60:
        total_ticket_price = ticket_price_senior + ticket_price_junior
        print(simple_colors.yellow(f"total ticket price:\n{total_ticket_price}\n"))
    elif not age_check >= 60:
        total_ticket_price = ticket_price_junior
        print(simple_colors.yellow(f"total ticket price:\n{total_ticket_price}\n"))
    elif not age_check < 60:
        total_ticket_price = ticket_price_senior
        print(simple_colors.yellow(f"total ticket price:\n{total_ticket_price}\n"))

food_name_list=[]
snack_name_list =[]
if cotraveller_num>0:
    print(simple_colors.green("two trains are availabe per day\n"))
    train_time = input("enter your choice of train time-input:morning or evening\n")
    print(simple_colors.yellow(f"train time {train_time}\n"))
    if train_time == "morning":
        print(simple_colors.blue("your train number is D101.food service is only available.But snacks are not available\n"))
        food_choice = input ("do you prefer the food service?enter yes or no")
        food_choice = str(food_choice)
        print(simple_colors.cyan(f"food choice{food_choice}"))
        if food_choice == 'yes':
            food_dict = {'breakfast':'poori','lunch':"pongal",'poori_price':50,'pongal_price':35}
            print(f"food show case:{food_dict}\n")
            num_order = input("enter your number of order")
            num_order = int (num_order)
            print(simple_colors.cyan(f"number of order{num_order}\n"))
            for food_name in range (0,num_order):
                food_name = input("Enter your order:poori or pongal")
                food_name = str (food_name)
                food_name_list.append(food_name)
        else:
            print("it seems you have not opted for the food choice\n")
    elif train_time == "evening":
        print("your train number is D102.snacks service is only available. not food service\n")
        snacks_choice = input ("do you prefer the snacks service?enter yes or no")
        snacks_choice = (snacks_choice)
        print(simple_colors.red(f"choice of snacks is:{snacks_choice}\n"))
        if snacks_choice == 'yes':
            snacks_dict = {'snackA':"apple",'apple_price':30,'snackB':'cookies','cookies_price':20}
            print(simple_colors.green(f"snacks showcase:{snacks_dict}\n"))
            num_order = input("enter your number of order:")
            num_order = int (num_order)
            print(simple_colors.yellow(f"number of order: {num_order}\n"))
            for food_name in range (0,num_order):
                food_name = input("Enter your order:apple or cookies")
                food_name = str (food_name)
                food_name_list.append(food_name)
        else:
            print(simple_colors.blue("it seems you have not opted for the food choice\n"))
    else:
       print(simple_colors.red("enter your choice of train time correctly!\n"))
else:
    print(simple_colors.cyan("showing the details of trains are allowed only for passengers!first you book the ticket"))
print(simple_colors.green(f"food name list: {food_name_list}"))

#)condition setting
for food_name in food_name_list:
    if food_name == "poori" or food_name == "pongal":    
    #) number of pooris
        poori_count = food_name_list.count("poori")
        print(simple_colors.blue(f"number of poori: {poori_count}\n"))

    #) total poori price
        poori_price = poori_count*50
        print(simple_colors.red(f"total poori price:{poori_price}\n"))
    
        #) number of pongal
        pongal_count = food_name_list.count("pongal")
        print(simple_colors.green(f"number of pongal:{pongal_count}\n"))

        #) total price of pongal
        pongal_price = pongal_count*35
        print(simple_colors.yellow(f"total pongal price:{pongal_price}\n"))

        #) total food price
        total_price =  poori_price + pongal_price
        print(simple_colors.blue(f"total food price: {total_price}\n"))
        break;
    if food_name == "apple" or food_name == "cookies":
        #)apple count
        apple_count = food_name_list.count('apple')
        print(simple_colors.green(f"(apple):{apple_count}\n"))

        #) total apple price
        apple_price = apple_count*30
        print(simple_colors.yellow(f"total apple price{apple_price}\n"))

        #) cookies count
        cookies_count = food_name_list.count("cookies")
        print(simple_colors.red(f"(cookies):{cookies_count}\n"))

        #) cookies price
        cookies_price = cookies_count*20
        print(simple_colors.cyan(f"total cookies price: {cookies_price}\n"))

        #) conctd snacks price
        total_price = apple_price + cookies_price
        print(simple_colors.green(f"total snacks price: {total_price}\n"))
        break;

cotrallevers_df.drop(columns=['cotrallevers_name','cotrallevers_age'],inplace=True)
# Out:
# letters are case sensetive.use uppercase and lower case carefully
#
# source is:
#  chennai
#
# destination is:
#  salem
#
# one stop is:
#  attur
# Enter your name: A
# booker name:A
#
# length of passenger name:1
# your age: 23
# booker age23
# destination available:salem or attur
# enter your choice of destination: salem
#  4 types of coach is available:AC1/AC2/AC3/SLEEPER
# fare of AC1:800,
# fare of AC2:600
# fare of AC3:400
# fare of AC3:200
# fare of SLEEPER:100
# your choice of coach: SLEEPER
# how many trallverllers? 2
# number of cotravellers: 2

# %%
import pandas as pd
booker_df = pd.DataFrame()
booker_df['source'] = [source]
booker_df['destination'] = [destination]
booker_df['one_stop'] = [one_stop]
booker_df['booker_name'] = [passenger_name]
booker_df['booker_age'] = [passenger_age]
booker_df['coach_preferred'] = [coach_preferred]
booker_df['cotraveller_num'] = [cotraveller_num]
booker_df
# Out:
#     source destination one_stop booker_name  booker_age coach_preferred  \
# 0  chennai       salem    attur       vivek          45             AC1
#
#    cotraveller_num
# 0                2
